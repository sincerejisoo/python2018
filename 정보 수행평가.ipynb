# %%
import csv
f=open('서울시 공영주차장 안내 정보.csv', encoding='utf8')
g=open('주차장수.csv')
h=open('116_DT_MLTM_5498_20180614075305.csv')
data1 = list(csv.reader(f))
data2 = list(csv.reader(g))
data3 = list(csv.reader(h))
parkingnum1 = 0 #공영주차장
parkingnum_0 = 0
parkingnum_1 = 0
parkingnum_2 = 0
parkingnum_3 = 0
parkingnum_4 = 0
parkingnum_5 = 0
parkingnum_6 = 0
parkingnum_7 = 0
parkingnum_8 = 0
parkingnum_9 = 0
parkingnum_10 = 0
parkingnum_11 = 0
parkingnum_12 = 0
parkingnum_13 = 0
parkingnum_14 = 0
parkingnum_15 = 0
parkingnum_16 = 0
parkingnum_17 = 0
parkingnum_18 = 0
parkingnum_19 = 0
parkingnum_20 = 0
parkingnum_21 = 0
parkingnum_22 = 0
parkingnum_23 = 0
parkingnum_24 = 0
parkingnum2 = []  #공동주택 주차장
district = ["강남구", "강동구", "강북구", "강서구", "관악구", "광진구", "구로구", "금천구", "노원구", "도봉구", "동대문구", "동작구", "마포구", "서대문구", "서초구", "성동구", "성북구", "송파구", "양천구", "영등포구", "용산구", "은평구", "종로구", "중구", "중랑구"]
carnum = []
seoul = 0
rownum1 = 0 

for row in data1:
    rownum1 = rownum1 + 1
    if rownum1 >1:
        parkingnum1 = parkingnum1 + int(row[10])
for row in data1:
    if district[0] in row[2]:
        parkingnum_0 = parkingnum_0 + int(row[10])
    elif district[1] in row[2]:
        parkingnum_1 = parkingnum_1 + int(row[10])    
    elif district[2] in row[2]:
        parkingnum_2 = parkingnum_2 + int(row[10]) 
    elif district[3] in row[2]:
        parkingnum_3 = parkingnum_3 + int(row[10]) 
    elif district[4] in row[2]:
        parkingnum_4 = parkingnum_4 + int(row[10])    
    elif district[5] in row[2]:
        parkingnum_5 = parkingnum_5 + int(row[10]) 
    elif district[6] in row[2]:
        parkingnum_6 = parkingnum_6 + int(row[10])    
    elif district[7] in row[2]:
        parkingnum_7 = parkingnum_7 + int(row[10])    
    elif district[8] in row[2]:
        parkingnum_8 = parkingnum_8 + int(row[10]) 
    elif district[9] in row[2]:
        parkingnum_9 = parkingnum_9 + int(row[10]) 
    elif district[10] in row[2]:
        parkingnum_10 = parkingnum_10 + int(row[10])    
    elif district[11] in row[2]:
        parkingnum_11 = parkingnum_11 + int(row[10]) 
    elif district[12] in row[2]:
        parkingnum_12 = parkingnum_12 + int(row[10]) 
    elif district[13] in row[2]:
        parkingnum_13 = parkingnum_13 + int(row[10])    
    elif district[14] in row[2]:
        parkingnum_14 = parkingnum_14 + int(row[10]) 
    elif district[15] in row[2]:
        parkingnum_15 = parkingnum_15 + int(row[10]) 
    elif district[16] in row[2]:
        parkingnum_16 = parkingnum_16 + int(row[10])    
    elif district[17] in row[2]:
        parkingnum_17 = parkingnum_17 + int(row[10]) 
    elif district[18] in row[2]:
        parkingnum_18 = parkingnum_18 + int(row[10])  
    elif district[19] in row[2]:
        parkingnum_19 = parkingnum_19 + int(row[10])    
    elif district[20] in row[2]:
        parkingnum_20 = parkingnum_20 + int(row[10]) 
    elif district[21] in row[2]:
        parkingnum_21 = parkingnum_21 + int(row[10]) 
    elif district[22] in row[2]:
        parkingnum_22 = parkingnum_22 + int(row[10])    
    elif district[23] in row[2]:
        parkingnum_23 = parkingnum_23 + int(row[10]) 
    elif district[24] in row[2]:
        parkingnum_24 = parkingnum_24 + int(row[10])     
for row in data2:
    if row[0]=="2017" and row[1]==district[0]:
        parkingnum2.append(int(row[-1]))
    elif row[0]=="2017" and row[1]==district[1]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[2]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[3]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[4]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[5]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[6]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[7]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[8]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[9]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[10]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[11]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[12]:
        parkingnum2.append(int(row[-1]))     
    elif row[0]=="2017" and row[1]==district[13]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[14]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[15]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[16]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[17]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[18]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[19]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[20]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[21]:
        parkingnum2.append(int(row[-1]))  
    elif row[0]=="2017" and row[1]==district[22]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[23]:
        parkingnum2.append(int(row[-1])) 
    elif row[0]=="2017" and row[1]==district[24]:
        parkingnum2.append(int(row[-1]))   
    else:
        parkingnum2.append(int(row[-1]))  
for row in data3:
    if row[1]=='계' and row[2]=='총계' and row[3] == '자가용':
        seoul = int(row[-1])
    elif row[1]==district[0] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[1] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[2] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[3] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))    
    elif row[1]==district[4] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[5] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[6] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[7] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))    
    elif row[1]==district[8] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[9] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[10] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[11] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))    
    elif row[1]==district[12] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[13] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[14] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[15] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))   
    elif row[1]==district[16] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))    
    elif row[1]==district[17] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[18] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[19] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[20] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))    
    elif row[1]==district[21] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[22] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[23] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1]))
    elif row[1]==district[24] and row[2]=='총계' and row[3] == '자가용':
        carnum.append(int(row[-1])) 
    elif row[0]=='end of the document':
        carnum.append(seoul)
if carnum[25]>parkingnum1+parkingnum2[25]:
    print('서울시에는 주차장이 부족합니다')
    print(carnum[25]-parkingnum1-parkingnum2[25])
else:
    print('서울시에는 주차장이 조금 남습니다.')
    print(-carnum[25]+parkingnum1+parkingnum2[25])        
if carnum[0]>parkingnum_0+parkingnum2[0]:
    print('강남구에는 주차장이 부족합니다.')
    print(carnum[0]-parkingnum_0-parkingnum2[0])
else:
    print('강남구에는 주차장이 조금 남습니다.')#강남구 0
    print(-carnum[0]+parkingnum_0+parkingnum2[0])  
if carnum[1]>parkingnum_1+parkingnum2[1]:
    print('강동구에는 주차장이 부족합니다.')
    print(carnum[1]-parkingnum_1-parkingnum2[1])
else:
    print('강동구에는 주차장이 조금 남습니다.')
    print(-carnum[1]+parkingnum_1+parkingnum2[1]) #강동구 1
if carnum[2]>parkingnum_2+parkingnum2[2]:
    print('강북구에는 주차장이 부족합니다.')
    print(carnum[2]-parkingnum_2-parkingnum2[2])
else:
    print('강북구에는 주차장이 조금 남습니다.')
    print(-carnum[2]+parkingnum_2+parkingnum2[2]) #강북구 2
if carnum[3]>parkingnum_3+parkingnum2[3]:
    print('강서구에는 주차장이 부족합니다.')
    print(carnum[3]-parkingnum_3-parkingnum2[3])
else:
    print('강서구에는 주차장이 조금 남습니다.')
    print(-carnum[3]+parkingnum_3+parkingnum2[3])#강서구 3
if carnum[4]>parkingnum_4+parkingnum2[4]:
    print('관악구에는 주차장이 부족합니다.')
    print(carnum[4]-parkingnum_4-parkingnum2[4])
else:
    print('관악구에는 주차장이 조금 남습니다.')
    print(-carnum[4]+parkingnum_4+parkingnum2[4]) #관악구 4 
if carnum[5]>parkingnum_5+parkingnum2[5]:
    print('광진구에는 주차장이 부족합니다.')
    print(carnum[5]-parkingnum_5-parkingnum2[5])
else:
    print('광진구에는 주차장이 조금 남습니다.')
    print(-carnum[5]+parkingnum_5+parkingnum2[5]) #광진구 5
if carnum[6]>parkingnum_6+parkingnum2[6]:
    print('구로구에는 주차장이 부족합니다.')
    print(carnum[6]-parkingnum_6-parkingnum2[6])
else:
    print('구로구에는 주차장이 조금 남습니다.')
    print(-carnum[6]+parkingnum_6+parkingnum2[6]) #구로구 6
if carnum[7]>parkingnum_7+parkingnum2[7]:
    print('금천구에는 주차장이 부족합니다.')
    print(carnum[7]-parkingnum_7-parkingnum2[7])
else:
    print('금천구에는 주차장이 조금 남습니다.')
    print(-carnum[7]+parkingnum_7+parkingnum2[7])#금천구 7
if carnum[8]>parkingnum_8+parkingnum2[8]:
    print('노원구에는 주차장이 부족합니다.')
    print(carnum[8]-parkingnum_8-parkingnum2[8])
else:
    print('노원구에는 주차장이 조금 남습니다.')
    print(-carnum[8]+parkingnum_8+parkingnum2[8])  #노원구 8
if carnum[9]>parkingnum_9+parkingnum2[9]:
    print('도봉구에는 주차장이 부족합니다.')
    print(carnum[9]-parkingnum_9-parkingnum2[9])
else:
    print('도봉구에는 주차장이 조금 남습니다.')
    print(-carnum[9]+parkingnum_9+parkingnum2[9]) #도봉구 9
if carnum[10]>parkingnum_10+parkingnum2[10]:
    print('동대문구에는 주차장이 부족합니다.')
    print(carnum[10]-parkingnum_10-parkingnum2[10])
else:
    print('동대문구에는 주차장이 조금 남습니다.')
    print(-carnum[10]+parkingnum_10+parkingnum2[10]) #동대문구 10
if carnum[11]>parkingnum_11+parkingnum2[11]:
    print('동작구에는 주차장이 부족합니다.')
    print(carnum[11]-parkingnum_11-parkingnum2[11])
else:
    print('동작구에는 주차장이 조금 남습니다.')
    print(-carnum[11]+parkingnum_11+parkingnum2[11]) #동작구 11  
if carnum[12]>parkingnum_12+parkingnum2[12]:
    print('마포구에는 주차장이 부족합니다.')
    print(carnum[12]-parkingnum_12-parkingnum2[12])
else:
    print('마포구에는 주차장이 조금 남습니다.')
    print(-carnum[12]+parkingnum_12+parkingnum2[12]) #마포구 12 
if carnum[13]>parkingnum_13+parkingnum2[13]:
    print('서대문구에는 주차장이 부족합니다.')
    print(carnum[13]-parkingnum_13-parkingnum2[13])
else:
    print('서대문구에는 주차장이 조금 남습니다.')
    print(-carnum[13]+parkingnum_13+parkingnum2[13]) #서대문구 13
if carnum[14]>parkingnum_14+parkingnum2[14]:
    print('서초구에는 주차장이 부족합니다.')
    print(carnum[14]-parkingnum_14-parkingnum2[14])
else:
    print('서초구에는 주차장이 조금 남습니다.')
    print(-carnum[14]+parkingnum_14+parkingnum2[14]) #서초구 14
if carnum[15]>parkingnum_15+parkingnum2[15]:
    print('성동구에는 주차장이 부족합니다.')
    print(carnum[15]-parkingnum_15-parkingnum2[15])
else:
    print('성동구에는 주차장이 조금 남습니다.')
    print(-carnum[15]+parkingnum_15+parkingnum2[15])#성동구 15
if carnum[16]>parkingnum_16+parkingnum2[16]:
    print('성북구에는 주차장이 부족합니다.')
    print(carnum[16]-parkingnum_16-parkingnum2[16])
else:
    print('성북구에는 주차장이 조금 남습니다.')
    print(-carnum[16]+parkingnum_16+parkingnum2[16]) #성북구 16 
if carnum[17]>parkingnum_17+parkingnum2[17]:
    print('송파구에는 주차장이 부족합니다.')
    print(carnum[17]-parkingnum_17-parkingnum2[17])
else:
    print('송파구에는 주차장이 조금 남습니다.')
    print(-carnum[17]+parkingnum_17+parkingnum2[17]) #송파구 17
if carnum[18]>parkingnum_18+parkingnum2[18]:
    print('양천구에는 주차장이 부족합니다.')
    print(carnum[18]-parkingnum_18-parkingnum2[18])
else:
    print('양천구에는 주차장이 조금 남습니다.')
    print(-carnum[18]+parkingnum_18+parkingnum2[18]) #양천구 18
if carnum[19]>parkingnum_19+parkingnum2[19]:
    print('영등포구에는 주차장이 부족합니다.')
    print(carnum[19]-parkingnum_19-parkingnum2[19])
else:
    print('영등포구에는 주차장이 조금 남습니다.')
    print(-carnum[19]+parkingnum_19+parkingnum2[19])#영등포구 19
if carnum[20]>parkingnum_20+parkingnum2[20]:
    print('용산구에는 주차장이 부족합니다.')
    print(carnum[20]-parkingnum_20-parkingnum2[20])
else:
    print('용산구에는 주차장이 조금 남습니다.')
    print(-carnum[20]+parkingnum_20+parkingnum2[20])  #용산구 20
if carnum[21]>parkingnum_21+parkingnum2[21]:
    print('은평구에는 주차장이 부족합니다.')
    print(carnum[21]-parkingnum_21-parkingnum2[21])
else:
    print('은평구에는 주차장이 조금 남습니다.')
    print(-carnum[21]+parkingnum_21+parkingnum2[21]) #은평구 21
if carnum[22]>parkingnum_22+parkingnum2[22]:
    print('종로구에는 주차장이 부족합니다.')
    print(carnum[22]-parkingnum_22-parkingnum2[22])
else:
    print('종로구에는 주차장이 조금 남습니다.')
    print(-carnum[22]+parkingnum_22+parkingnum2[22]) #종로구 22
if carnum[23]>parkingnum_23+parkingnum2[23]:
    print('중구에는 주차장이 부족합니다.')
    print(carnum[23]-parkingnum_23-parkingnum2[23])
else:
    print('중구에는 주차장이 조금 남습니다.')
    print(-carnum[23]+parkingnum_23+parkingnum2[23]) #중구 23  
if carnum[24]>parkingnum_24+parkingnum2[24]:
    print('중랑구에는 주차장이 부족합니다.')
    print(carnum[24]-parkingnum_12-parkingnum2[24])
else:
    print('중랑구에는 주차장이 조금 남습니다.')
    print(-carnum[24]+parkingnum_24+parkingnum2[24]) #중랑구 24
# Out:
# 서울시에는 주차장이 조금 남습니다.
# 131099
# 강남구에는 주차장이 부족합니다.
# 59892
# 강동구에는 주차장이 부족합니다.
# 22484
# 강북구에는 주차장이 부족합니다.
# 18591
# 강서구에는 주차장이 조금 남습니다.
# 141394
# 관악구에는 주차장이 부족합니다.
# 33428
# 광진구에는 주차장이 부족합니다.
# 25038
# 구로구에는 주차장이 부족합니다.
# 29398
# 금천구에는 주차장이 부족합니다.
# 4948
# 노원구에는 주차장이 조금 남습니다.
# 6798
# 도봉구에는 주차장이 부족합니다.
# 15171
# 동대문구에는 주차장이 조금 남습니다.
# 7236
# 동작구에는 주차장이 부족합니다.
# 23194
# 마포구에는 주차장이 조금 남습니다.
# 33020
# 서대문구에는 주차장이 부족합니다.
# 28333
# 서초구에는 주차장이 부족합니다.
# 5500
# 성동구에는 주차장이 조금 남습니다.
# 181298
# 성북구에는 주차장이 부족합니다.
# 17966
# 송파구에는 주차장이 부족합니다.
# 47466
# 양천구에는 주차장이 조금 남습니다.
# 36987
# 영등포구에는 주차장이 부족합니다.
# 8874
# 용산구에는 주차장이 부족합니다.
# 1413
# 은평구에는 주차장이 부족합니다.
# 13694
# 종로구에는 주차장이 조금 남습니다.
# 5686
# 중구에는 주차장이 조금 남습니다.
# 39887
# 중랑구에는 주차장이 조금 남습니다.
# 34183
